# %%
# %run implementation_workbook.ipynb
# Out:
# Our output
# [0.00023031 0.00060937 0.00077062 0.00064296 0.0001957 ]
# Correct output
# [0.00023031 0.00060937 0.00077062 0.00064296 0.0001957 ]
# (10, 2)
# Correct output
# [0.00970558 0.01602077 0.00982328 0.00977784 0.0134664  0.01508864
#  0.0030866  0.00871177 0.00366591 0.00223946]
# Our output
# [0.00970558 0.01602077 0.00982328 0.00977784 0.0134664  0.01508864
#  0.0030866  0.00871177 0.00366591 0.00223946]
# (9, 2)
# (9, 2)
# Iteration Number:
#  1
# Loglikelihood
#  -157.21602757929963
# Iteration Number:
#  2
# Loglikelihood
#  -23.727959016304553
# Iteration Number:
#  3
# Loglikelihood
#  -21.333134099878315
# Iteration Number:
#  4
# Loglikelihood
#  -17.32680990015335
# Iteration Number:
#  5
# Loglikelihood
#  -16.438255287188053
# Iteration Number:
#  6
# Loglikelihood
#  -16.438255287188053

# %%
#ASSIGNMENT 8
import os
import scipy.io as sio
# load data 
cwd = os.getcwd()
file_name = '5_gaussians.npy'
path_to_data = cwd + '/data/'+file_name
assert os.path.exists(path_to_data), "The path does not excist."
gaussians = np.load(path_to_data).T
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-12-2ba43a3cffcb> in <module>
#       6 file_name = '5_gaussians.npy'
#       7 path_to_data = cwd + '/data/'+file_name
# ----> 8 assert os.path.exists(path_to_data), "The path does not excist."
#       9 gaussians = np.load(path_to_data).T
#
# AssertionError: The path does not excist.

# %%
# Visualize data
plt.plot(gaussians[:,0], gaussians[:,1], 'o')
